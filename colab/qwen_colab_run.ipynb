# %%
# %pip install -q transformers accelerate qwen-vl-utils pillow pandas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 68.1 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount("/content/drive")
# %cd /content/drive/MyDrive/image-processing-with-deep-learning
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/image-processing-with-deep-learning

# %%
# %python src/6_qwen_vlm_test.py \
    --model Qwen/Qwen2-VL-7B-Instruct \
    --image afis_200.png \
    --device cuda
# Out:
# Model yükleniyor: Qwen/Qwen2-VL-7B-Instruct (cuda, torch.float16)...
# config.json: 100% 1.20k/1.20k [00:00<00:00, 3.21MB/s]
# ...
# model.safetensors.index.json: 100% 56.5k/56.5k [00:00<00:00, 111MB/s]
# ...
# Fetching 5 files: 100% 5/5 [09:33<00:00, 114.64s/it]
# Download complete: 100% 16.6G/16.6G [09:33<00:00, 28.9MB/s]
# Loading weights: 100% 730/730 [01:09<00:00, 10.44it/s]
# generation_config.json: 100% 244/244 [00:00<00:00, 1.04MB/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# preprocessor_config.json: 100% 347/347 [00:00<00:00, 1.29MB/s]
# chat_template.json: 100% 1.05k/1.05k [00:00<00:00, 2.35MB/s]
# tokenizer_config.json: 100% 4.19k/4.19k [00:00<00:00, 13.0MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 111MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 114MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 139MB/s]
#
# Qwen-VL çalışıyor (afis_200.png)...
#
# ...
# 🔍 TEST EDİLEN GÖRSEL: afis_200.png (CSV satır 200)
# ...
#
# 🤖 QWEN-VL HAM ÇIKTI:
# ...

# %%
# %python src/7_evaluate_qwen.py \
    --model Qwen/Qwen2-VL-7B-Instruct \
    --device cuda \
    --limit 5
# Out:
# Değerlendirilecek afiş: 5 (toplam hedef: 5)
# Model: Qwen/Qwen2-VL-7B-Instruct | Cihaz: cuda
# Tahmini süre: ~8–11 dakika
#
# Model yükleniyor: Qwen/Qwen2-VL-7B-Instruct (cuda, torch.float16)...
# ...
# Fetching 5 files: 100% 5/5 [00:00<00:00, 25575.02it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading weights: 100% 730/730 [01:11<00:00, 10.28it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# Qwen-VL: 100% 5/5 [07:58<00:00, 95.72s/it]
#
# ...
# 📊 QWEN-VL DEĞERLENDİRME ÖZETİ
# ...
# Toplam afiş: 5
# JSON ayrıştırma başarısı: 100.0%
# Tüm alanları doğru afiş: 4 (80.0%)
# Ortalama doğru alan / afiş: 6.60 / 7
#
# Alan bazında doğruluk:
#   isim         → %100.0
#   unvan        → %100.0
#   yayin_gunu   → % 80.0
#   yayin_adi    → % 80.0
#   tag1         → %100.0
#   tag2         → %100.0
#   tag3         → %100.0
#
# Detaylı sonuçlar: /content/drive/MyDrive/image-processing-with-deep-learning/src/../results/evaluation_qwen.csv
# ...

# %%
# %python src/7_evaluate_qwen.py \
    --model Qwen/Qwen2-VL-7B-Instruct \
    --device cuda \
    --resume
